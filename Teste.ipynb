# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardorobertson/MVP_Analise_de_Dados_e_Boas_Praticas/blob/main/Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# url_1 = 'https://github.com/ricardorobertson/LEITURA/raw/main/202511.CSV'

url_1 = 'https://github.com/ricardorobertson/MVP_Analise_de_Dados_e_Boas_Praticas/raw/main/202501.CSV'

# Lê o CSV diretamente da URL
# df1 = pd.read_csv(url_1,on_bad_lines='skip')
# df2 = pd.read_csv(url_2,on_bad_lines='skip')
# df = pd.read_csv(url)

# Exibe as primeiras linhas para verificar
# print(df.head())

# import pandas as pd
df1 = pd.read_csv(url_1,sep=';')
#df1 = pd.read_csv(url_1,sep=';', encoding='utf-8')
# df2 = pd.read_csv(url_2)
# Concatenar verticalmente
# result = pd.concat([df1, df2], ignore_index=True)

print(df1.head())
# Out:
#     ANO  MES EMPRESA ORIGEM DESTINO   TARIFA  ASSENTOS
# 0  2025    1     ABJ   SBSV    SIRI   800,00         6
# 1  2025    1     ABJ   SBSV    SIRI  1000,00         3
# 2  2025    1     ABJ   SBSV    SIRI  1400,00         1
# 3  2025    1     ABJ   SBSV    SNCL   550,00        41
# 4  2025    1     ABJ   SBSV    SNCL   700,00        55
